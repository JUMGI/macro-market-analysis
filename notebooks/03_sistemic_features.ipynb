# %%
from quant_research.config.paths import ASSET_FEATURE_PATH

print(ASSET_FEATURE_PATH)
# Out:
# /home/jumgi/macro-market-analysis/data/features/asset

# %%
import os

os.listdir(ASSET_FEATURE_PATH / "Momentum")
# Out:
# ['XLE.parquet', 'BTC.parquet', 'QQQ.parquet', 'SPY.parquet']

# %%
from quant_research.features.builders.panel_builder import build_feature_panel

panel = build_feature_panel(
    assets=["BTC","SPY"],
    families=["Momentum"]
)

panel.head()
# Out:
# feature    MOM_126     MOM_126_ACC     MOM_126_ACC_S     MOM_126_PCTL      \
# asset          BTC SPY         BTC SPY           BTC SPY          BTC SPY
# Date
# 2015-01-02     NaN NaN         NaN NaN           NaN NaN          NaN NaN
# 2015-01-03     NaN NaN         NaN NaN           NaN NaN          NaN NaN
# 2015-01-04     NaN NaN         NaN NaN           NaN NaN          NaN NaN
# 2015-01-05     NaN NaN         NaN NaN           NaN NaN          NaN NaN
# 2015-01-06     NaN NaN         NaN NaN           NaN NaN          NaN NaN
#
# feature    MOM_126_STAB      ... MOM_ALIGN_Z      MSI      MSI_ACC_S      \
# asset               BTC SPY  ...         BTC SPY  BTC  SPY       BTC SPY
# Date                         ...
# 2015-01-02          NaN NaN  ...         NaN NaN  0.0  0.0       NaN NaN
# 2015-01-03          NaN NaN  ...         NaN NaN  0.0  0.0       NaN NaN
# 2015-01-04          NaN NaN  ...         NaN NaN  0.0  0.0       NaN NaN
# ...
